# %%
from google.colab import drive

drive.mount('/content/drive')

# TODO: Enter the path in your Drive of the assignment.
# e.g. 'cs231n/assignments/assignment2/'
FOLDERNAME = 'Colab Notebooks/cs231n/assignments/assignment2/'

assert FOLDERNAME is not None, "[!] Enter the foldername."
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Collect Submission - Zip + Generate PDF
#
# Run this notebook once you have completed all the other notebooks: `FullyConnectedNets.ipynb`, `BatchNormalization.ipynb`, `Dropout.ipynb`, `ConvolutionalNetworks.ipynb`, `PyTorch.ipynb`).
#
# It will:
#
# * Generate a zip file of your code (`.py` and `.ipynb`) called `a2_code_submission.zip`.
# * Convert all notebooks into a single PDF file called `a2_inline_submission.pdf`.
#
# If your submission for this step was successful, you should see the following display message:
#
# `### Done! Please submit a2_code_submission.zip and the a2_inline_submission.pdf to Gradescope. ###`
#
# Make sure to download the zip and pdf file locally to your computer, then submit to Gradescope. Congrats on succesfully completing the assignment!

# %%
# %cd /content/drive/MyDrive/$FOLDERNAME
# !sudo apt-get update
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !pip install PyPDF2
# !bash collectSubmission.sh
# Out:
# /content/drive/My Drive/Colab Notebooks/cs231n/assignments/assignment2
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# texlive-fonts-recommended is already the newest version (2021.20220204-1).
# texlive-plain-generic is already the newest version (2021.20220204-1).
# texlive-xetex is already the newest version (2021.20220204-1).
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# ### Zipping file ###
# ### Creating PDFs ###
# Created PDF FullyConnectedNets.ipynb.
# Created PDF BatchNormalization.ipynb.
# Created PDF Dropout.ipynb.
# Created PDF ConvolutionalNetworks.ipynb.
# Created PDF PyTorch.ipynb.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/makepdf.py", line 46, in <module>
#     main(args.notebooks, args.pdf_filename)
#   File "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/makepdf.py", line 31, in main
#     merger.append(pdf)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 319, in append
#     self.merge(len(self.pages), fileobj, outline_item, pages, import_outline)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 194, in merge
#     stream, encryption_obj = self._create_stream(fileobj)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 263, in _create_stream
#     stream = FileIO(fileobj, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: 'FullyConnectedNets.pdf'

# %%
import os
pdf_files = ["FullyConnectedNets.pdf", "BatchNormalization.pdf", "Dropout.pdf", "ConvolutionalNetworks.pdf", "PyTorch.pdf"]
for pdf in pdf_files:
    print(f"{pdf}: {'Exists' if os.path.exists(pdf) else 'Not Found'}")
# Out:
# FullyConnectedNets.pdf: Not Found
# BatchNormalization.pdf: Not Found
# Dropout.pdf: Not Found
# ConvolutionalNetworks.pdf: Not Found
# PyTorch.pdf: Not Found

# %%
# !python makepdf.py --notebooks "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/FullyConnectedNets.ipynb" \
                  "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/BatchNormalization.ipynb" \
                  "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/Dropout.ipynb" \
                  "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/ConvolutionalNetworks.ipynb" \
                  "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/PyTorch.ipynb" \
                  --pdf_filename assignment2.pdf
# Out:
# Created PDF /content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/FullyConnectedNets.ipynb.
# Created PDF /content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/BatchNormalization.ipynb.
# Created PDF /content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/Dropout.ipynb.
# Created PDF /content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/ConvolutionalNetworks.ipynb.
# Created PDF /content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/PyTorch.ipynb.
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/makepdf.py", line 46, in <module>
#     main(args.notebooks, args.pdf_filename)
#   File "/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/makepdf.py", line 31, in main
#     merger.append(pdf)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 319, in append
#     self.merge(len(self.pages), fileobj, outline_item, pages, import_outline)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_utils.py", line 417, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 194, in merge
#     stream, encryption_obj = self._create_stream(fileobj)
#   File "/usr/local/lib/python3.10/dist-packages/PyPDF2/_merger.py", line 263, in _create_stream
#     stream = FileIO(fileobj, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/cs231n/assignments/assignment2/FullyConnectedNets.pdf'
